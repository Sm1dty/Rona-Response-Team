# %% [markdown]
# ## New York State COVID Response Analysis
# This notebook contains the work to identify associations between the  state governmental response and the COVID-19 case count throughout the pandemic.
#
#
# ## Data Cleanup
# As with most data mining projects, we will need to clean up the given data file in order to focus on the goal at hand. The "all-states-history.csv" file is a dataset of U.S. COVID-19 cases and deaths dating from the start of the pandemic to 11/29/20 and was sourced from [The Covid Tracking Project](https://covidtracking.com/data). We are analyzing 3 periods throughout this timeline:
#
# - Early Breakout (Early March -> May)
# - Summer (June -> August)
# - Fall/Present (September -> Late November)
#
# We will divide up the data into 3 different frames according to these periods.
#
# In order to analyze with state policy actions, we will merge data from the [Oxford Covid-19 Government Response Tracker](https://github.com/OxCGRT/covid-policy-tracker) github dataset titled 'state-policies.csv'.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import squarify
import seaborn as sns
from datetime import datetime as dt

# for market basket analysis
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# Need to a way to discretize and format data too be suitable for apriori analysis. The function below will discretize the necessary columns into bins and set the values to strings according to the bin they are placed in.

# %%
def discretize_data(arr, k):
    cols = arr.columns
    for i in cols:
        bin_range = pd.cut(arr[i],k)
        col_copy = arr[i].astype('str')
        for j in range(len(col_copy)):
            col_copy[j] = i + "" +str(bin_range[j])
            
        arr[i] = col_copy

# %% [markdown]
# Initializing the dataframes

# %%
# COVID tracking project data
covid_data = pd.read_csv('all-states-history.csv')

# state plicy data
policy_data = pd.read_csv('state-policies.csv')
# Out:
# C:\Users\98dyl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Cleaning up Covid data to only include New York instances and the appropriate attributes

# %%
#isolating the columns we need
columns_to_show = ['date','deathIncrease','hospitalizedIncrease','negativeIncrease','positiveIncrease','totalTestResultsIncrease']

#isolating only for NY data and putting in order March->November
covid_clean_data = covid_data[covid_data['state'] == 'NY']
covid_clean_data = covid_clean_data[columns_to_show]
covid_clean_data = covid_clean_data.iloc[::-1]
covid_clean_data = covid_clean_data.reset_index(drop = True).fillna(0)

# %% [markdown]
# Now we can divide up the covid data into the 3 distinct periods (as well as keep a datframe for the overall period)

# %%
# getting start and end dates for dividing up into periods

EB_start = dt.strptime(covid_clean_data['date'][0],"%Y-%m-%d")
EB_end = dt.strptime("2020-05-31", "%Y-%m-%d")

S_start = dt.strptime("2020-06-01", "%Y-%m-%d")
S_end = dt.strptime("2020-08-31", "%Y-%m-%d") 

FP_start = dt.strptime("2020-09-01", "%Y-%m-%d")
FP_end = dt.strptime(covid_clean_data['date'][len(covid_clean_data)-1], "%Y-%m-%d")

#reindexing for weekly processing 
covid_clean_data['date'] = covid_clean_data['date'].astype('datetime64[ns]')
covid_clean_data = covid_clean_data.set_index('date')

#dividing up into different time periods
full_period = covid_clean_data

early_breakout = covid_clean_data[EB_start:EB_end].reset_index(drop=True)

summer = covid_clean_data[S_start:S_end].reset_index(drop=True)

fall = covid_clean_data[FP_start:FP_end].reset_index(drop=True)

# %%
covid_clean_data.head()
# Out:
#             deathIncrease  hospitalizedIncrease  negativeIncrease  \
# date
# 2020-03-02              0                     0                 0
# 2020-03-03              0                     0                 0
# 2020-03-04              0                     0                 9
# 2020-03-05              0                     0                18
# 2020-03-06              0                     0                70
#
#             positiveIncrease  totalTestResultsIncrease
# date
# 2020-03-02                 0                         0
# 2020-03-03                 1                         1
# 2020-03-04                 0                         9
# 2020-03-05                 2                        20
# 2020-03-06                22                        92

# %% [markdown]
# After dividing up the data into the periods, we can discretize into the k bins using the "discretize_data" function implemented earlier.

# %%
discretize_data(full_period,10)
discretize_data(early_breakout,8)
discretize_data(summer,8)
discretize_data(fall,8)

# %%
# converting remaining non-sum columns to weekly index
#remaining_cols = covid_clean_data[['state','death','deathConfirmed','hospitalized', 'negative','positive','totalTestResults']]
#remaining_cols = remaining_cols.resample('W').backfill().reset_index()
#remaining_cols.head(39)

#merging and resetting the datframe order to be more clear
#covid_clean_data = pd.merge(remaining_cols, weekly_data, left_index = True, right_index = True).fillna(0)
#covid_clean_data = covid_clean_data[['date','state','death','deathIncrease','deathConfirmed','hospitalized', 'hospitalizedIncrease','negative',
                        #'negativeIncrease','positive', 'positiveIncrease','totalTestResults','totalTestResultsIncrease']]

# %% [markdown]
# Cleaning up state policy dataframe:

# %%
#isolating data only about the current state of interest, New York
policy_clean_data = policy_data[policy_data['RegionName'] == 'New York']
#deleting rows whose dates are outside of the scope of this project
policy_clean_data = policy_clean_data.iloc[60:] #delete the first 60 rows due to their January - February dates
policy_clean_data = policy_clean_data.iloc[:-3,] #as well as the last 3 rows due to their December dates

#declaring and extracting columns of interest from the original dataset
columns_of_interest = ['Date', 'C1_School closing', 'C2_Workplace closing', 
                       'C3_Cancel public events', 'C4_Restrictions on gatherings', 'C6_Stay at home requirements', 
                       'C7_Restrictions on internal movement', 'C8_International travel controls', 
                       'H1_Public information campaigns', 'H2_Testing policy', 'H3_Contact tracing', 
                       'H4_Emergency investment in healthcare', 
                       'H6_Facial Coverings']
policy_clean_data = policy_clean_data[columns_of_interest].fillna(0)

# reformating date section and range of dates needed
policy_clean_data = policy_clean_data.reset_index(drop = True)

date_col = policy_clean_data['Date'].astype('str')
for i in range(policy_clean_data.shape[0]):
    date_col[i] = dt.strptime(date_col[i], "%Y%m%d")
    
policy_clean_data['Date'] = date_col

start_date = dt.strptime('20200306', "%Y%m%d")
end_date = dt.strptime('20201129', "%Y%m%d")

policy_clean_data = policy_clean_data.rename(columns = {"Date": "date"})

policy_clean_data = policy_clean_data.set_index('date')

# %% [markdown]
# Changing values of policy_clean_data to the type of policy each number corresponds to:

# %%
#C1_School closing
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(0, 'no measures, school closing')
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(1, 'recommend closing or all schools open with alterations')
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(2, 'require closing only some levels or categories')
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(3, 'require closing all levels, school closing')
#C2_Workplace closing
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(0, 'no measures, workplace closing')
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(1, 'recommend closing (or recommend work from home)')
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(2, 'require closing (or work from home) for some sectors or categories of workers')
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(3, 'require closing (or work from home) for all-but-essential workplaces (eg grocery stores, doctors)')
#C3_Cancel public events
policy_clean_data['C3_Cancel public events'] = policy_clean_data['C3_Cancel public events'].replace(0, 'no measures, cancel public events')
policy_clean_data['C3_Cancel public events'] = policy_clean_data['C3_Cancel public events'].replace(1, 'recommend cancelling public events')
policy_clean_data['C3_Cancel public events'] = policy_clean_data['C3_Cancel public events'].replace(2, 'require cancelling public events')
#C4_Restrictions on gatherings                                                                                            
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(0, 'no restrictions on gatherings')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(1, 'restrictions on very large gatherings (the limit is above 1000 people)')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(2, 'restrictions on gatherings between 101-1000 people')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(3, 'restrictions on gatherings between 11-100 people')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(4, 'restrictions on gatherings of 10 people or less')
#C6_Stay at home requirements                                                                                            
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(0, 'no measures for stay at home requirement')
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(1, 'recommend not leaving house')
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(2, 'require not leaving house with exceptions for "essential" activities')
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(3, 'require not leaving house with minimal exceptions')
#C7_Restrictions on internal movement
policy_clean_data['C7_Restrictions on internal movement'] = policy_clean_data['C7_Restrictions on internal movement'].replace(0, 'no measures on restrictions on internal movement')
policy_clean_data['C7_Restrictions on internal movement'] = policy_clean_data['C7_Restrictions on internal movement'].replace(1, 'recommend not to travel between regions/cities')
policy_clean_data['C7_Restrictions on internal movement'] = policy_clean_data['C7_Restrictions on internal movement'].replace(2, 'internal movement restrictions in place')
#C8_International travel controls
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(0, 'no restrictions on international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(1, 'screening arrivals on international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(2, 'quarantine arrivals from some or all regions for international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(3, 'ban arrivals from some regions for international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(4, 'ban on all regions or total border closure')
#H1_Public information campaigns
policy_clean_data['H1_Public information campaigns'] = policy_clean_data['H1_Public information campaigns'].replace(0, 'no Covid-19 public information campaign')
policy_clean_data['H1_Public information campaigns'] = policy_clean_data['H1_Public information campaigns'].replace(1, 'public officials urging caution about Covid-19')
policy_clean_data['H1_Public information campaigns'] = policy_clean_data['H1_Public information campaigns'].replace(2, 'coordinated public information campaign ')
#H2_Testing policy
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(0, 'no testing policy')
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(1, 'only those who both (a) have symptoms AND (b) meet specific criteria')
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(2, 'testing of anyone showing Covid-19 symptoms')
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(3, 'open public testing')
#H3_Contact tracing
policy_clean_data['H3_Contact tracing'] = policy_clean_data['H3_Contact tracing'].replace(0, 'no contact tracing')
policy_clean_data['H3_Contact tracing'] = policy_clean_data['H3_Contact tracing'].replace(1, 'limited contact tracing; not done for all cases')
policy_clean_data['H3_Contact tracing'] = policy_clean_data['H3_Contact tracing'].replace(2, 'comprehensive contact tracing; done for all identified cases')
#H4_Emergency investment in healthcare
### not a code, simply records the monetary value in USD
policy_clean_data['H4_Emergency investment in healthcare'] = policy_clean_data['H4_Emergency investment in healthcare'].mask(policy_clean_data['H4_Emergency investment in healthcare'] > 0, 'investment')
policy_clean_data['H4_Emergency investment in healthcare'] = policy_clean_data['H4_Emergency investment in healthcare'].replace(0, 'no new spending that day')

#H6_Facial Coverings
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(0, 'no policy on facial coverings')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(1, 'recommended facial coverings')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(2, 'facial coverings required in some specified shared/public spaces')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(3, 'facial coverings required in all shared/public spaces')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(4, 'facial coverings required outside the home at all times')

# %% [markdown]
# We decided to drop some columns that skewed the Apriori results and didn't offer much info in general:

# %%
policy_clean_data = policy_clean_data.drop(['H1_Public information campaigns','H4_Emergency investment in healthcare','H3_Contact tracing'], axis = 1)

# %% [markdown]
# Dividing up the policy data into the seperate periods:

# %%
early_breakout_policy = policy_clean_data[EB_start:EB_end].reset_index(drop=True)

summer_policy = policy_clean_data[S_start:S_end].reset_index(drop=True)

fall_policy = policy_clean_data[FP_start:FP_end].reset_index(drop=True)

# %%
EB_C1 = early_breakout_policy["C1_School closing"]

# %% [markdown]
# Merging case and policy dataframes to create the basket:

# %%
NY_basket_full = pd.merge(full_period, policy_clean_data,left_index = True, right_index = True)

NY_basket_EB = pd.merge(early_breakout, early_breakout_policy,left_index = True, right_index = True)

NY_basket_summer = pd.merge(summer, summer_policy,left_index = True, right_index = True)

NY_basket_fall = pd.merge(fall, fall_policy,left_index = True, right_index = True)

# %% [markdown]
# ## Analysis
#
# Important NY Stats:
#
# - Population (ny.gov estimate): 19,378,102
# - Land Area (estimate): 47,126.4 sq. mi.
# - Population Density: 411.20 people/sq. mi.
#
# Below will be a breakdown of each of the time periods (including overall time) to see if any noticeable associations formed between increases and state policy.

# %% [markdown]
# ## Full Pandemic Period
#
# #### All Policies Included

# %%
from wordcloud import WordCloud

#full pandemic period

all_elements = NY_basket_full.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in NY', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %%
basket_array_full = NY_basket_full.values
basket_cols_full = NY_basket_full.columns
te_full = TransactionEncoder()
te_dataset_full = te_full.fit(basket_array_full).transform(basket_array_full)

NY_te_basket_full = pd.DataFrame(te_dataset_full, columns = te_full.columns_)

# %%
# full period

NY_freq_itemsets_full = apriori(NY_te_basket_full, min_support=0.4, use_colnames=True)
NY_freq_itemsets_full['length'] = NY_freq_itemsets_full['itemsets'].apply(lambda x: len(x))
rules_full = association_rules(NY_freq_itemsets_full, metric="conviction", min_threshold=0.3)
rules_full["antecedent_len"] = rules_full["antecedents"].apply(lambda x: len(x))

# %%
trimmed_rules = rules_full[(rules_full['confidence'] >= 0.7) & (rules_full['conviction'] >= 3)]
trimmed_rules.head(30)
# Out:
#                                           antecedents  \
# 2                       (deathIncrease(-0.951, 95.1])
# 3               (hospitalizedIncrease(-3.424, 342.4])
# 5           (internal movement restrictions in place)
# 7                               (open public testing)
# 9                 (positiveIncrease(-11.571, 1157.1])
# 13                      (recommend not leaving house)
# 16  (require closing (or work from home) for some ...
# 21          (internal movement restrictions in place)
# 23                              (open public testing)
# 26  (facial coverings required in all shared/publi...
# 38          (internal movement restrictions in place)
# 41                              (open public testing)
# 43                (positiveIncrease(-11.571, 1157.1])
# 46                      (recommend not leaving house)
# 50  (require closing (or work from home) for some ...
# 52          (internal movement restrictions in place)
# 54          (internal movement restrictions in place)
# 56          (internal movement restrictions in place)
# 60                              (open public testing)
# 62                      (recommend not leaving house)
# 66  (require closing (or work from home) for some ...
# 72  (require closing (or work from home) for some ...
# 73                (positiveIncrease(-11.571, 1157.1])
# 78  (require closing (or work from home) for all-b...
# 82       (require closing all levels, school closing)
# 84  (restrictions on gatherings of 10 people or less)
# 86  (require closing (or work from home) for some ...
# 88  (require closing (or work from home) for all-b...
# 92  (restrictions on gatherings of 10 people or less)
# 93                 (require cancelling public events)
#
#                                           consequents  antecedent support  \
# 2               (hospitalizedIncrease(-3.424, 342.4])            0.776557
# 3                       (deathIncrease(-0.951, 95.1])            0.794872
# 5                       (deathIncrease(-0.951, 95.1])            0.578755
# 7                       (deathIncrease(-0.951, 95.1])            0.721612
# 9                       (deathIncrease(-0.951, 95.1])            0.527473
# 13                      (deathIncrease(-0.951, 95.1])            0.688645
# 16                      (deathIncrease(-0.951, 95.1])            0.483516
# 21  (facial coverings required in all shared/publi...            0.578755
# 23  (facial coverings required in all shared/publi...            0.721612
# 26  (quarantine arrivals from some or all regions ...            0.831502
# 38              (hospitalizedIncrease(-3.424, 342.4])            0.578755
# 41              (hospitalizedIncrease(-3.424, 342.4])            0.721612
# 43              (hospitalizedIncrease(-3.424, 342.4])            0.527473
# 46              (hospitalizedIncrease(-3.424, 342.4])            0.688645
# 50              (hospitalizedIncrease(-3.424, 342.4])            0.483516
# 52                              (open public testing)            0.578755
# 54  (quarantine arrivals from some or all regions ...            0.578755
# 56                      (recommend not leaving house)            0.578755
# 60  (quarantine arrivals from some or all regions ...            0.721612
# 62                              (open public testing)            0.688645
# 66                              (open public testing)            0.483516
# 72                (positiveIncrease(-11.571, 1157.1])            0.483516
# 73  (require closing (or work from home) for some ...            0.527473
# 78  (quarantine arrivals from some or all regions ...            0.479853
# 82  (quarantine arrivals from some or all regions ...            0.589744
# 84  (quarantine arrivals from some or all regions ...            0.578755
# 86                      (recommend not leaving house)            0.483516
# 88                 (require cancelling public events)            0.479853
# 92                 (require cancelling public events)            0.578755
# 93  (restrictions on gatherings of 10 people or less)            0.670330
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 2             0.794872  0.761905    0.981132  1.234327  0.144642   10.871795
# 3             0.776557  0.761905    0.958525  1.234327  0.144642    5.387464
# 5             0.776557  0.578755    1.000000  1.287736  0.129319         inf
# 7             0.776557  0.692308    0.959391  1.235442  0.131935    5.502289
# 9             0.776557  0.527473    1.000000  1.287736  0.117860         inf
# 13            0.776557  0.688645    1.000000  1.287736  0.153873         inf
# 16            0.776557  0.483516    1.000000  1.287736  0.108038         inf
# 21            0.831502  0.578755    1.000000  1.202643  0.097519         inf
# 23            0.831502  0.721612    1.000000  1.202643  0.121590         inf
# 26            0.934066  0.831502    1.000000  1.070588  0.054824         inf
# 38            0.794872  0.578755    1.000000  1.258065  0.118719         inf
# 41            0.794872  0.717949    0.994924  1.251678  0.144360   40.410256
# 43            0.794872  0.527473    1.000000  1.258065  0.108199         inf
# 46            0.794872  0.684982    0.994681  1.251373  0.137597   38.564103
# 50            0.794872  0.479853    0.992424  1.248534  0.095520   27.076923
# 52            0.721612  0.578755    1.000000  1.385787  0.161118         inf
# 54            0.934066  0.578755    1.000000  1.070588  0.038160         inf
# 56            0.688645  0.578755    1.000000  1.452128  0.180198         inf
# 60            0.934066  0.721612    1.000000  1.070588  0.047579         inf
# 62            0.721612  0.641026    0.930851  1.289961  0.144092    4.025923
# 66            0.721612  0.446886    0.924242  1.280803  0.097975    3.674725
# 72            0.527473  0.446886    0.924242  1.752210  0.191845    6.237363
# 73            0.483516  0.446886    0.847222  1.752210  0.191845    3.380619
# 78            0.934066  0.479853    1.000000  1.070588  0.031639         inf
# 82            0.934066  0.589744    1.000000  1.070588  0.038884         inf
# 84            0.934066  0.578755    1.000000  1.070588  0.038160         inf
# 86            0.688645  0.483516    1.000000  1.452128  0.150545         inf
# 88            0.670330  0.479853    1.000000  1.491803  0.158193         inf
# 92            0.670330  0.578755    1.000000  1.491803  0.190798         inf
# 93            0.578755  0.578755    0.863388  1.491803  0.190798    3.083516
#
#     antecedent_len
# 2                1
# 3                1
# 5                1
# 7                1
# 9                1
# 13               1
# 16               1
# 21               1
# 23               1
# 26               1
# 38               1
# 41               1
# 43               1
# 46               1
# 50               1
# 52               1
# 54               1
# 56               1
# 60               1
# 62               1
# 66               1
# 72               1
# 73               1
# 78               1
# 82               1
# 84               1
# 86               1
# 88               1
# 92               1
# 93               1

# %% [markdown]
# ## Early Breakout/Spring Period

# %%
#Early breakout period

all_elements = NY_basket_EB.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in NY during Spring', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %% [markdown]
# As we can maybe see from the chart above, the "screeing arrivals on international travel" shows up in 100% of the days, so we can leave that out to avoid any skew.

# %%
basket_array_EB = NY_basket_EB.values
basket_cols_EB = NY_basket_EB.columns
te_EB = TransactionEncoder()
te_dataset_EB = te_EB.fit(basket_array_EB).transform(basket_array_EB)

NY_te_basket_EB = pd.DataFrame(te_dataset_EB, columns = te_EB.columns_)
NY_te_basket_EB = NY_te_basket_EB.drop("screening arrivals on international travel", axis = 1)

# %%
# EB period

NY_freq_itemsets_EB = apriori(NY_te_basket_EB, min_support=0.4, use_colnames=True)
NY_freq_itemsets_EB['length'] = NY_freq_itemsets_EB['itemsets'].apply(lambda x: len(x))
rules_EB = association_rules(NY_freq_itemsets_EB, metric="conviction", min_threshold=0.3)
rules_EB["antecedent_len"] = rules_EB["antecedents"].apply(lambda x: len(x))

# %%
trimmed_rules_EB = rules_EB[(rules_EB['confidence'] >= 0.7) & (rules_EB['conviction'] >= 3) & (rules_EB['support'] >= 0.6)]
trimmed_rules_EB.head(30)
# Out:
#                                           antecedents  \
# 16   (recommend not to travel between regions/cities)
# 17  (quarantine arrivals from some or all regions ...
# 19  (quarantine arrivals from some or all regions ...
# 20  (require closing (or work from home) for all-b...
# 21  (quarantine arrivals from some or all regions ...
# 22       (require closing all levels, school closing)
# 23  (quarantine arrivals from some or all regions ...
# 24  (require not leaving house with exceptions for...
# 25  (quarantine arrivals from some or all regions ...
# 26  (restrictions on gatherings of 10 people or less)
# 27  (quarantine arrivals from some or all regions ...
# 28   (recommend not to travel between regions/cities)
# 30  (require closing (or work from home) for all-b...
# 31   (recommend not to travel between regions/cities)
# 32       (require closing all levels, school closing)
# 33   (recommend not to travel between regions/cities)
# 34  (require not leaving house with exceptions for...
# 35   (recommend not to travel between regions/cities)
# 36  (restrictions on gatherings of 10 people or less)
# 37   (recommend not to travel between regions/cities)
# 38  (require closing (or work from home) for all-b...
# 40       (require closing all levels, school closing)
# 42  (require not leaving house with exceptions for...
# 44  (restrictions on gatherings of 10 people or less)
# 46  (require closing (or work from home) for all-b...
# 47       (require closing all levels, school closing)
# 48  (require closing (or work from home) for all-b...
# 49  (require not leaving house with exceptions for...
# 50  (require closing (or work from home) for all-b...
# 51  (restrictions on gatherings of 10 people or less)
#
#                                           consequents  antecedent support  \
# 16  (quarantine arrivals from some or all regions ...            0.780220
# 17   (recommend not to travel between regions/cities)            0.802198
# 19                 (require cancelling public events)            0.802198
# 20  (quarantine arrivals from some or all regions ...            0.780220
# 21  (require closing (or work from home) for all-b...            0.802198
# 22  (quarantine arrivals from some or all regions ...            0.769231
# 23       (require closing all levels, school closing)            0.802198
# 24  (quarantine arrivals from some or all regions ...            0.780220
# 25  (require not leaving house with exceptions for...            0.802198
# 26  (quarantine arrivals from some or all regions ...            0.769231
# 27  (restrictions on gatherings of 10 people or less)            0.802198
# 28                 (require cancelling public events)            0.780220
# 30   (recommend not to travel between regions/cities)            0.780220
# 31  (require closing (or work from home) for all-b...            0.780220
# 32   (recommend not to travel between regions/cities)            0.769231
# 33       (require closing all levels, school closing)            0.780220
# 34   (recommend not to travel between regions/cities)            0.780220
# 35  (require not leaving house with exceptions for...            0.780220
# 36   (recommend not to travel between regions/cities)            0.769231
# 37  (restrictions on gatherings of 10 people or less)            0.780220
# 38                 (require cancelling public events)            0.780220
# 40                 (require cancelling public events)            0.769231
# 42                 (require cancelling public events)            0.780220
# 44                 (require cancelling public events)            0.769231
# 46       (require closing all levels, school closing)            0.780220
# 47  (require closing (or work from home) for all-b...            0.769231
# 48  (require not leaving house with exceptions for...            0.780220
# 49  (require closing (or work from home) for all-b...            0.780220
# 50  (restrictions on gatherings of 10 people or less)            0.780220
# 51  (require closing (or work from home) for all-b...            0.769231
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 16            0.802198  0.780220    1.000000  1.246575  0.154329         inf
# 17            0.780220  0.780220    0.972603  1.246575  0.154329    8.021978
# 19            0.890110  0.802198    1.000000  1.123457  0.088154         inf
# 20            0.802198  0.780220    1.000000  1.246575  0.154329         inf
# 21            0.780220  0.780220    0.972603  1.246575  0.154329    8.021978
# 22            0.802198  0.769231    1.000000  1.246575  0.152156         inf
# 23            0.769231  0.769231    0.958904  1.246575  0.152156    5.615385
# 24            0.802198  0.780220    1.000000  1.246575  0.154329         inf
# 25            0.780220  0.780220    0.972603  1.246575  0.154329    8.021978
# 26            0.802198  0.769231    1.000000  1.246575  0.152156         inf
# 27            0.769231  0.769231    0.958904  1.246575  0.152156    5.615385
# 28            0.890110  0.780220    1.000000  1.123457  0.085738         inf
# 30            0.780220  0.780220    1.000000  1.281690  0.171477         inf
# 31            0.780220  0.780220    1.000000  1.281690  0.171477         inf
# 32            0.780220  0.769231    1.000000  1.281690  0.169062         inf
# 33            0.769231  0.769231    0.985915  1.281690  0.169062   16.384615
# 34            0.780220  0.780220    1.000000  1.281690  0.171477         inf
# 35            0.780220  0.780220    1.000000  1.281690  0.171477         inf
# 36            0.780220  0.769231    1.000000  1.281690  0.169062         inf
# 37            0.769231  0.769231    0.985915  1.281690  0.169062   16.384615
# 38            0.890110  0.780220    1.000000  1.123457  0.085738         inf
# 40            0.890110  0.769231    1.000000  1.123457  0.084531         inf
# 42            0.890110  0.780220    1.000000  1.123457  0.085738         inf
# 44            0.890110  0.769231    1.000000  1.123457  0.084531         inf
# 46            0.769231  0.769231    0.985915  1.281690  0.169062   16.384615
# 47            0.780220  0.769231    1.000000  1.281690  0.169062         inf
# 48            0.780220  0.780220    1.000000  1.281690  0.171477         inf
# 49            0.780220  0.780220    1.000000  1.281690  0.171477         inf
# 50            0.769231  0.769231    0.985915  1.281690  0.169062   16.384615
# 51            0.780220  0.769231    1.000000  1.281690  0.169062         inf
#
#     antecedent_len
# 16               1
# 17               1
# 19               1
# 20               1
# 21               1
# 22               1
# 23               1
# 24               1
# 25               1
# 26               1
# 27               1
# 28               1
# 30               1
# 31               1
# 32               1
# 33               1
# 34               1
# 35               1
# 36               1
# 37               1
# 38               1
# 40               1
# 42               1
# 44               1
# 46               1
# 47               1
# 48               1
# 49               1
# 50               1
# 51               1

# %% [markdown]
# ## Summer Period

# %%
#summer period

all_elements = NY_basket_summer.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in NY during summer', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %%
basket_array_summer = NY_basket_summer.values
basket_cols_summer = NY_basket_summer.columns
te_summer = TransactionEncoder()
te_dataset_summer = te_summer.fit(basket_array_summer).transform(basket_array_summer)

NY_te_basket_summer = pd.DataFrame(te_dataset_summer, columns = te_summer.columns_)
#NY_te_basket_summer = NY_te_basket_summer.drop(["facial coverings required in some specified shared/public spaces", 
 #                                               ""])

# %%
# summer period

NY_freq_itemsets_summer = apriori(NY_te_basket_summer, min_support=0.6, use_colnames=True)
NY_freq_itemsets_summer['length'] = NY_freq_itemsets_summer['itemsets'].apply(lambda x: len(x))
rules_summer = association_rules(NY_freq_itemsets_summer, metric="conviction", min_threshold=0.3)
rules_summer["antecedent_len"] = rules_summer["antecedents"].apply(lambda x: len(x))

# %%
trimmed_rules_summer = rules_summer[(rules_summer['confidence'] >= 0.7) & 
                                    (rules_summer['support'] >= 0.7) & 
                                    (rules_summer['conviction'] > 1) &
                                    (rules_summer['lift'] > 1)]
trimmed_rules_summer.head(40)
# Out:
#                                            antecedents  \
# 16               (hospitalizedIncrease(-0.158, 19.75])
# 17           (internal movement restrictions in place)
# 22               (hospitalizedIncrease(-0.158, 19.75])
# 23                       (recommend not leaving house)
# 24               (hospitalizedIncrease(-0.158, 19.75])
# 25   (require closing (or work from home) for some ...
# 34           (internal movement restrictions in place)
# 35                       (recommend not leaving house)
# 36   (require closing (or work from home) for some ...
# 37           (internal movement restrictions in place)
# 60   (require closing (or work from home) for some ...
# 61                       (recommend not leaving house)
# 72   (facial coverings required in all shared/publi...
# 73   (facial coverings required in all shared/publi...
# 76           (internal movement restrictions in place)
# 77               (hospitalizedIncrease(-0.158, 19.75])
# 90   (facial coverings required in all shared/publi...
# 91   (facial coverings required in all shared/publi...
# 94               (hospitalizedIncrease(-0.158, 19.75])
# 95                       (recommend not leaving house)
# 96   (facial coverings required in all shared/publi...
# 97   (facial coverings required in all shared/publi...
# 100  (require closing (or work from home) for some ...
# 101              (hospitalizedIncrease(-0.158, 19.75])
# 126  (facial coverings required in all shared/publi...
# 127  (facial coverings required in all shared/publi...
# 130          (internal movement restrictions in place)
# 131                      (recommend not leaving house)
# 132  (facial coverings required in all shared/publi...
# 133  (facial coverings required in all shared/publi...
# 136  (require closing (or work from home) for some ...
# 137          (internal movement restrictions in place)
# 204  (facial coverings required in all shared/publi...
# 205  (facial coverings required in all shared/publi...
# 208  (require closing (or work from home) for some ...
# 209                      (recommend not leaving house)
# 241  (hospitalizedIncrease(-0.158, 19.75], open pub...
# 242  (internal movement restrictions in place, open...
# 243              (hospitalizedIncrease(-0.158, 19.75])
# 244          (internal movement restrictions in place)
#
#                                            consequents  antecedent support  \
# 16           (internal movement restrictions in place)            0.967391
# 17               (hospitalizedIncrease(-0.158, 19.75])            0.739130
# 22                       (recommend not leaving house)            0.967391
# 23               (hospitalizedIncrease(-0.158, 19.75])            0.923913
# 24   (require closing (or work from home) for some ...            0.967391
# 25               (hospitalizedIncrease(-0.158, 19.75])            0.923913
# 34                       (recommend not leaving house)            0.739130
# 35           (internal movement restrictions in place)            0.923913
# 36           (internal movement restrictions in place)            0.923913
# 37   (require closing (or work from home) for some ...            0.739130
# 60                       (recommend not leaving house)            0.923913
# 61   (require closing (or work from home) for some ...            0.923913
# 72               (hospitalizedIncrease(-0.158, 19.75])            0.739130
# 73           (internal movement restrictions in place)            0.967391
# 76   (facial coverings required in all shared/publi...            0.739130
# 77   (facial coverings required in all shared/publi...            0.967391
# 90                       (recommend not leaving house)            0.967391
# 91               (hospitalizedIncrease(-0.158, 19.75])            0.923913
# 94   (facial coverings required in all shared/publi...            0.967391
# 95   (facial coverings required in all shared/publi...            0.923913
# 96               (hospitalizedIncrease(-0.158, 19.75])            0.923913
# 97   (require closing (or work from home) for some ...            0.967391
# 100  (facial coverings required in all shared/publi...            0.923913
# 101  (facial coverings required in all shared/publi...            0.967391
# 126                      (recommend not leaving house)            0.739130
# 127          (internal movement restrictions in place)            0.923913
# 130  (facial coverings required in all shared/publi...            0.739130
# 131  (facial coverings required in all shared/publi...            0.923913
# 132          (internal movement restrictions in place)            0.923913
# 133  (require closing (or work from home) for some ...            0.739130
# 136  (facial coverings required in all shared/publi...            0.923913
# 137  (facial coverings required in all shared/publi...            0.739130
# 204                      (recommend not leaving house)            0.923913
# 205  (require closing (or work from home) for some ...            0.923913
# 208  (facial coverings required in all shared/publi...            0.923913
# 209  (facial coverings required in all shared/publi...            0.923913
# 241          (internal movement restrictions in place)            0.967391
# 242              (hospitalizedIncrease(-0.158, 19.75])            0.739130
# 243  (internal movement restrictions in place, open...            0.967391
# 244  (hospitalizedIncrease(-0.158, 19.75], open pub...            0.739130
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 16             0.739130  0.739130    0.764045  1.033708  0.024102    1.105590
# 17             0.967391  0.739130    1.000000  1.033708  0.024102         inf
# 22             0.923913  0.923913    0.955056  1.033708  0.030128    1.692935
# 23             0.967391  0.923913    1.000000  1.033708  0.030128         inf
# 24             0.923913  0.923913    0.955056  1.033708  0.030128    1.692935
# 25             0.967391  0.923913    1.000000  1.033708  0.030128         inf
# 34             0.923913  0.739130    1.000000  1.082353  0.056238         inf
# 35             0.739130  0.739130    0.800000  1.082353  0.056238    1.304348
# 36             0.739130  0.739130    0.800000  1.082353  0.056238    1.304348
# 37             0.923913  0.739130    1.000000  1.082353  0.056238         inf
# 60             0.923913  0.923913    1.000000  1.082353  0.070298         inf
# 61             0.923913  0.923913    1.000000  1.082353  0.070298         inf
# 72             0.967391  0.739130    1.000000  1.033708  0.024102         inf
# 73             0.739130  0.739130    0.764045  1.033708  0.024102    1.105590
# 76             0.967391  0.739130    1.000000  1.033708  0.024102         inf
# 77             0.739130  0.739130    0.764045  1.033708  0.024102    1.105590
# 90             0.923913  0.923913    0.955056  1.033708  0.030128    1.692935
# 91             0.967391  0.923913    1.000000  1.033708  0.030128         inf
# 94             0.923913  0.923913    0.955056  1.033708  0.030128    1.692935
# 95             0.967391  0.923913    1.000000  1.033708  0.030128         inf
# 96             0.967391  0.923913    1.000000  1.033708  0.030128         inf
# 97             0.923913  0.923913    0.955056  1.033708  0.030128    1.692935
# 100            0.967391  0.923913    1.000000  1.033708  0.030128         inf
# 101            0.923913  0.923913    0.955056  1.033708  0.030128    1.692935
# 126            0.923913  0.739130    1.000000  1.082353  0.056238         inf
# 127            0.739130  0.739130    0.800000  1.082353  0.056238    1.304348
# 130            0.923913  0.739130    1.000000  1.082353  0.056238         inf
# 131            0.739130  0.739130    0.800000  1.082353  0.056238    1.304348
# 132            0.739130  0.739130    0.800000  1.082353  0.056238    1.304348
# 133            0.923913  0.739130    1.000000  1.082353  0.056238         inf
# 136            0.739130  0.739130    0.800000  1.082353  0.056238    1.304348
# 137            0.923913  0.739130    1.000000  1.082353  0.056238         inf
# 204            0.923913  0.923913    1.000000  1.082353  0.070298         inf
# 205            0.923913  0.923913    1.000000  1.082353  0.070298         inf
# 208            0.923913  0.923913    1.000000  1.082353  0.070298         inf
# 209            0.923913  0.923913    1.000000  1.082353  0.070298         inf
# 241            0.739130  0.739130    0.764045  1.033708  0.024102    1.105590
# 242            0.967391  0.739130    1.000000  1.033708  0.024102         inf
# 243            0.739130  0.739130    0.764045  1.033708  0.024102    1.105590
# 244            0.967391  0.739130    1.000000  1.033708  0.024102         inf
#
#      antecedent_len
# 16                1
# 17                1
# 22                1
# 23                1
# 24                1
# 25                1
# 34                1
# 35                1
# 36                1
# 37                1
# 60                1
# 61                1
# 72                2
# 73                2
# 76                1
# 77                1
# 90                2
# 91                2
# 94                1
# 95                1
# 96                2
# 97                2
# 100               1
# 101               1
# 126               2
# 127               2
# 130               1
# 131               1
# 132               2
# 133               2
# 136               1
# 137               1
# 204               2
# 205               2
# 208               1
# 209               1
# 241               2
# 242               2
# 243               1
# 244               1

# %% [markdown]
# ## Fall Period

# %%
#fall period

all_elements = NY_basket_fall.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in NY during Fall', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %% [markdown]
# Now that we have the data set up as a series of 'transactions' with items (basket), we just need to encode the items and then use Apriori analysis and find association rules:

# %%
basket_array_fall = NY_basket_fall.values
basket_cols_fall = NY_basket_fall.columns
te_fall = TransactionEncoder()
te_dataset_fall = te_fall.fit(basket_array_fall).transform(basket_array_fall)

NY_te_basket_fall = pd.DataFrame(te_dataset_fall, columns = te_fall.columns_)

# %%
NY_te_basket_full.head()
# Out:
#    deathIncrease(-0.951, 95.1]  deathIncrease(190.2, 285.3]  \
# 0                         True                        False
# 1                         True                        False
# 2                         True                        False
# 3                         True                        False
# 4                         True                        False
#
#    deathIncrease(285.3, 380.4]  deathIncrease(380.4, 475.5]  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    deathIncrease(475.5, 570.6]  deathIncrease(570.6, 665.7]  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    deathIncrease(665.7, 760.8]  deathIncrease(760.8, 855.9]  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    deathIncrease(855.9, 951.0]  deathIncrease(95.1, 190.2]  ...  \
# 0                        False                       False  ...
# 1                        False                       False  ...
# 2                        False                       False  ...
# 3                        False                       False  ...
# 4                        False                       False  ...
#
#    totalTestResultsIncrease(-219.442, 21944.2]  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#    totalTestResultsIncrease(109721.0, 131665.2]  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    totalTestResultsIncrease(131665.2, 153609.4]  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    totalTestResultsIncrease(153609.4, 175553.6]  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    totalTestResultsIncrease(175553.6, 197497.8]  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    totalTestResultsIncrease(197497.8, 219442.0]  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    totalTestResultsIncrease(21944.2, 43888.4]  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    totalTestResultsIncrease(43888.4, 65832.6]  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    totalTestResultsIncrease(65832.6, 87776.8]  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    totalTestResultsIncrease(87776.8, 109721.0]
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
# [5 rows x 78 columns]

# %% [markdown]
# Performing apriori and then creating association rules for all periods:

# %%
# fall period

NY_freq_itemsets_fall = apriori(NY_te_basket_fall, min_support=0.4, use_colnames=True)
NY_freq_itemsets_fall['length'] = NY_freq_itemsets_fall['itemsets'].apply(lambda x: len(x))
rules_fall = association_rules(NY_freq_itemsets_fall, metric="conviction", min_threshold=0.3)
rules_fall["antecedent_len"] = rules_fall["antecedents"].apply(lambda x: len(x))

# %% [markdown]
# Now we can mine for associations:

# %%
rules = pd.concat([rules_EB, rules_summer, rules_fall])
rules_EB.to_csv('New York Early Breakout Association Rules.csv')
rules_summer.to_csv('New York Summer Association Rules.csv')
rules_fall.to_csv('New York Fall Association Rules.csv')
rules.to_csv('New York Association Rules.csv')
