# %% [markdown]
# ## Oregon State COVID Response Analysis
# This notebook contains the work to identify associations between the Oregon state governmental response and the COVID-19 case count throughout the pandemic.
#
#
# ## Data Cleanup
# As with most data mining projects, we will need to clean up the given data file in order to focus on the goal at hand. The "all-states-history.csv" file is a dataset of U.S. COVID-19 cases and deaths dating from the start of the pandemic to 11/29/20 and was sourced from [The Covid Tracking Project](https://covidtracking.com/data). We are analyzing 3 periods throughout this timeline:
#
# - Early Breakout (Early March -> May)
# - Summer (June -> August)
# - Fall/Present (September -> Late November)
#
# We will divide up the data into 3 different frames according to these periods.
#
# In order to analyze with state policy actions, we will merge data from the [Oxford Covid-19 Government Response Tracker](https://github.com/OxCGRT/covid-policy-tracker) github dataset titled 'state-policies.csv'.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import squarify
import seaborn as sns
from datetime import datetime as dt

# for market basket analysis
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# Need to a way to discretize and format data too be suitable for apriori analysis. The function below will discretize the necessary columns into bins and set the values to strings according to the bin they are placed in.

# %%
def discretize_data(arr, k):
    cols = arr.columns
    for i in cols:
        bin_range = pd.cut(arr[i],k)
        col_copy = arr[i].astype('str')
        for j in range(len(col_copy)):
            col_copy[j] = i + "" +str(bin_range[j])
            
        arr[i] = col_copy

# %% [markdown]
# Initializing the dataframes

# %%
# COVID tracking project data
covid_data = pd.read_csv('all-states-history.csv')

# state plicy data
policy_data = pd.read_csv('state-policies.csv')
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Cleaning up Covid data to only include Oregon instances and the appropriate attributes

# %%
#isolating the columns we need
columns_to_show = ['date','deathIncrease','hospitalizedIncrease','negativeIncrease','positiveIncrease','totalTestResultsIncrease']

#isolating only for OR data and putting in order March->November
covid_clean_data = covid_data[covid_data['state'] == 'OR']
covid_clean_data = covid_clean_data[columns_to_show]
covid_clean_data = covid_clean_data.iloc[::-1]
covid_clean_data = covid_clean_data.reset_index(drop = True).fillna(0)

# %% [markdown]
# Now we can divide up the covid data into the 3 distinct periods (as well as keep a datframe for the overall period)

# %%
# getting start and end dates for dividing up into periods

EB_start = dt.strptime(covid_clean_data['date'][0],"%Y-%m-%d")
EB_end = dt.strptime("2020-05-31", "%Y-%m-%d")

S_start = dt.strptime("2020-06-01", "%Y-%m-%d")
S_end = dt.strptime("2020-08-31", "%Y-%m-%d") 

FP_start = dt.strptime("2020-09-01", "%Y-%m-%d")
FP_end = dt.strptime(covid_clean_data['date'][len(covid_clean_data)-1], "%Y-%m-%d")

#reindexing for weekly processing 
covid_clean_data['date'] = covid_clean_data['date'].astype('datetime64[ns]')
covid_clean_data = covid_clean_data.set_index('date')

#dividing up into different time periods
full_period = covid_clean_data

early_breakout = covid_clean_data[EB_start:EB_end].reset_index(drop=True)

summer = covid_clean_data[S_start:S_end].reset_index(drop=True)

fall = covid_clean_data[FP_start:FP_end].reset_index(drop=True)

# %% [markdown]
# After dividing up the data into the periods, we can discretize into the k bins using the "discretize_data" function implemented earlier.

# %%
discretize_data(full_period,10)
discretize_data(early_breakout,8)
discretize_data(summer,8)
discretize_data(fall,8)

# %% [markdown]
# Cleaning up state policy dataframe:

# %%
#isolating data only about the current state of interest, Oregon
policy_clean_data = policy_data[policy_data['RegionName'] == 'Oregon']
#deleting rows whose dates are outside of the scope of this project
policy_clean_data = policy_clean_data.iloc[60:] #delete the first 60 rows due to their January - February dates
policy_clean_data = policy_clean_data.iloc[:-3,] #as well as the last 3 rows due to their December dates

#declaring and extracting columns of interest from the original dataset
columns_of_interest = ['Date', 'C1_School closing', 'C2_Workplace closing', 
                       'C3_Cancel public events', 'C4_Restrictions on gatherings', 'C6_Stay at home requirements', 
                       'C7_Restrictions on internal movement', 'C8_International travel controls', 
                       'H1_Public information campaigns', 'H2_Testing policy', 'H3_Contact tracing', 
                       'H4_Emergency investment in healthcare', 
                       'H6_Facial Coverings']
policy_clean_data = policy_clean_data[columns_of_interest].fillna(0)

# reformating date section and range of dates needed
policy_clean_data = policy_clean_data.reset_index(drop = True)

date_col = policy_clean_data['Date'].astype('str')
for i in range(policy_clean_data.shape[0]):
    date_col[i] = dt.strptime(date_col[i], "%Y%m%d")
    
policy_clean_data['Date'] = date_col

start_date = dt.strptime('20200306', "%Y%m%d")
end_date = dt.strptime('20201129', "%Y%m%d")

policy_clean_data = policy_clean_data.rename(columns = {"Date": "date"})

policy_clean_data = policy_clean_data.set_index('date')

# %% [markdown]
# Changing values of policy_clean_data to the type of policy each number corresponds to:

# %%
#C1_School closing
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(0, 'no measures, school closing')
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(1, 'recommend closing or all schools open with alterations')
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(2, 'require closing only some levels or categories')
policy_clean_data['C1_School closing'] = policy_clean_data['C1_School closing'].replace(3, 'require closing all levels, school closing')
#C2_Workplace closing
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(0, 'no measures, workplace closing')
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(1, 'recommend closing (or recommend work from home)')
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(2, 'require closing (or work from home) for some sectors or categories of workers')
policy_clean_data['C2_Workplace closing'] = policy_clean_data['C2_Workplace closing'].replace(3, 'require closing (or work from home) for all-but-essential workplaces (eg grocery stores, doctors)')
#C3_Cancel public events
policy_clean_data['C3_Cancel public events'] = policy_clean_data['C3_Cancel public events'].replace(0, 'no measures, cancel public events')
policy_clean_data['C3_Cancel public events'] = policy_clean_data['C3_Cancel public events'].replace(1, 'recommend cancelling public events')
policy_clean_data['C3_Cancel public events'] = policy_clean_data['C3_Cancel public events'].replace(2, 'require cancelling public events')
#C4_Restrictions on gatherings                                                                                            
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(0, 'no restrictions on gatherings')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(1, 'restrictions on very large gatherings (the limit is above 1000 people)')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(2, 'restrictions on gatherings between 101-1000 people')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(3, 'restrictions on gatherings between 11-100 people')                                                                                              
policy_clean_data['C4_Restrictions on gatherings'] = policy_clean_data['C4_Restrictions on gatherings'].replace(4, 'restrictions on gatherings of 10 people or less')
#C6_Stay at home requirements                                                                                            
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(0, 'no measures for stay at home requirement')
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(1, 'recommend not leaving house')
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(2, 'require not leaving house with exceptions for "essential" activities')
policy_clean_data['C6_Stay at home requirements'] = policy_clean_data['C6_Stay at home requirements'].replace(3, 'require not leaving house with minimal exceptions')
#C7_Restrictions on internal movement
policy_clean_data['C7_Restrictions on internal movement'] = policy_clean_data['C7_Restrictions on internal movement'].replace(0, 'no measures on restrictions on internal movement')
policy_clean_data['C7_Restrictions on internal movement'] = policy_clean_data['C7_Restrictions on internal movement'].replace(1, 'recommend not to travel between regions/cities')
policy_clean_data['C7_Restrictions on internal movement'] = policy_clean_data['C7_Restrictions on internal movement'].replace(2, 'internal movement restrictions in place')
#C8_International travel controls
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(0, 'no restrictions on international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(1, 'screening arrivals on international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(2, 'quarantine arrivals from some or all regions for international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(3, 'ban arrivals from some regions for international travel')
policy_clean_data['C8_International travel controls'] = policy_clean_data['C8_International travel controls'].replace(4, 'ban on all regions or total border closure')
#H1_Public information campaigns
policy_clean_data['H1_Public information campaigns'] = policy_clean_data['H1_Public information campaigns'].replace(0, 'no Covid-19 public information campaign')
policy_clean_data['H1_Public information campaigns'] = policy_clean_data['H1_Public information campaigns'].replace(1, 'public officials urging caution about Covid-19')
policy_clean_data['H1_Public information campaigns'] = policy_clean_data['H1_Public information campaigns'].replace(2, 'coordinated public information campaign ')
#H2_Testing policy
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(0, 'no testing policy')
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(1, 'only those who both (a) have symptoms AND (b) meet specific criteria')
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(2, 'testing of anyone showing Covid-19 symptoms')
policy_clean_data['H2_Testing policy'] = policy_clean_data['H2_Testing policy'].replace(3, 'open public testing')
#H3_Contact tracing
policy_clean_data['H3_Contact tracing'] = policy_clean_data['H3_Contact tracing'].replace(0, 'no contact tracing')
policy_clean_data['H3_Contact tracing'] = policy_clean_data['H3_Contact tracing'].replace(1, 'limited contact tracing; not done for all cases')
policy_clean_data['H3_Contact tracing'] = policy_clean_data['H3_Contact tracing'].replace(2, 'comprehensive contact tracing; done for all identified cases')
#H4_Emergency investment in healthcare
### not a code, simply records the monetary value in USD
policy_clean_data['H4_Emergency investment in healthcare'] = policy_clean_data['H4_Emergency investment in healthcare'].mask(policy_clean_data['H4_Emergency investment in healthcare'] > 0, 'investment')
policy_clean_data['H4_Emergency investment in healthcare'] = policy_clean_data['H4_Emergency investment in healthcare'].replace(0, 'no new spending that day')

#H6_Facial Coverings
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(0, 'no policy on facial coverings')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(1, 'recommended facial coverings')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(2, 'facial coverings required in some specified shared/public spaces')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(3, 'facial coverings required in all shared/public spaces')
policy_clean_data['H6_Facial Coverings'] = policy_clean_data['H6_Facial Coverings'].replace(4, 'facial coverings required outside the home at all times')

# %% [markdown]
# We decided to drop some columns that skewed the Apriori results and didn't offer much info in general:

# %%
policy_clean_data = policy_clean_data.drop(['H1_Public information campaigns','H4_Emergency investment in healthcare','H3_Contact tracing'], axis = 1)

# %% [markdown]
# Dividing up the policy data into the seperate periods:

# %%
early_breakout_policy = policy_clean_data[EB_start:EB_end].reset_index(drop=True)

summer_policy = policy_clean_data[S_start:S_end].reset_index(drop=True)

fall_policy = policy_clean_data[FP_start:FP_end].reset_index(drop=True)

# %%
EB_C1 = early_breakout_policy["C1_School closing"]

# %% [markdown]
# Merging case and policy dataframes to create the basket:

# %%
OR_basket_full = pd.merge(full_period, policy_clean_data,left_index = True, right_index = True)

OR_basket_EB = pd.merge(early_breakout, early_breakout_policy,left_index = True, right_index = True)

OR_basket_summer = pd.merge(summer, summer_policy,left_index = True, right_index = True)

OR_basket_fall = pd.merge(fall, fall_policy,left_index = True, right_index = True)

# %% [markdown]
# ## Analysis
#
# Important OR Stats:
#
# - Population (census.gov estimate): 4,217,737
# - Land Area (estimate): 98,466 sq. mi.
# - Population Density (statista.com): 43.9 people/sq. mi.

# %% [markdown]
# ## Full Pandemic Period
#
# #### All Policies Included

# %%
from wordcloud import WordCloud

#full pandemic period

all_elements = OR_basket_full.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in OR', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %%
basket_array_full = OR_basket_full.values
basket_cols_full = OR_basket_full.columns
te_full = TransactionEncoder()
te_dataset_full = te_full.fit(basket_array_full).transform(basket_array_full)

OR_te_basket_full = pd.DataFrame(te_dataset_full, columns = te_full.columns_)

# %%
# full period

OR_freq_itemsets_full = apriori(OR_te_basket_full, min_support=0.4, use_colnames=True)
OR_freq_itemsets_full['length'] = OR_freq_itemsets_full['itemsets'].apply(lambda x: len(x))
rules_full = association_rules(OR_freq_itemsets_full, metric="conviction", min_threshold=0.3)
rules_full["antecedent_len"] = rules_full["antecedents"].apply(lambda x: len(x))

# %%
trimmed_rules = rules_full[(rules_full['confidence'] >= 0.7) & (rules_full['conviction'] >= 3)]
trimmed_rules.head(30)
# Out:
#                                            antecedents  \
# 0                         (deathIncrease(-0.021, 2.1])
# 11   (facial coverings required in all shared/publi...
# 13   (facial coverings required in all shared/publi...
# 15   (facial coverings required in all shared/publi...
# 20          (no measures for stay at home requirement)
# 30   (only those who both (a) have symptoms AND (b)...
# 32                   (positiveIncrease(-1.674, 167.4])
# 34    (recommend not to travel between regions/cities)
# 36                  (require cancelling public events)
# 38   (require closing (or work from home) for some ...
# 41        (require closing all levels, school closing)
# 43   (restrictions on gatherings of 10 people or less)
# 44                   (positiveIncrease(-1.674, 167.4])
# 53        (require closing all levels, school closing)
# 56    (recommend not to travel between regions/cities)
# 64   (require closing (or work from home) for some ...
# 67        (require closing all levels, school closing)
# 69   (restrictions on gatherings of 10 people or less)
# 76   (deathIncrease(-0.021, 2.1], only those who bo...
# 82   (deathIncrease(-0.021, 2.1], require cancellin...
# 88   (require closing (or work from home) for some ...
# 100  (require closing (or work from home) for some ...
# 107  (no measures for stay at home requirement, fac...
# 114  (no measures for stay at home requirement, fac...
# 119  (no measures for stay at home requirement, fac...
# 125  (require closing (or work from home) for some ...
# 126  (no measures for stay at home requirement, fac...
# 131  (recommend not to travel between regions/citie...
# 132  (no restrictions on international travel, faci...
# 135  (facial coverings required in all shared/publi...
#
#                                            consequents  antecedent support  \
# 0            (no restrictions on international travel)            0.509225
# 11           (no restrictions on international travel)            0.586716
# 13    (recommend not to travel between regions/cities)            0.586716
# 15                  (require cancelling public events)            0.586716
# 20           (no restrictions on international travel)            0.627306
# 30           (no restrictions on international travel)            0.797048
# 32           (no restrictions on international travel)            0.424354
# 34           (no restrictions on international travel)            0.771218
# 36           (no restrictions on international travel)            0.955720
# 38           (no restrictions on international travel)            0.878229
# 41           (no restrictions on international travel)            0.642066
# 43           (no restrictions on international travel)            0.767528
# 44   (only those who both (a) have symptoms AND (b)...            0.424354
# 53   (only those who both (a) have symptoms AND (b)...            0.642066
# 56                  (require cancelling public events)            0.771218
# 64                  (require cancelling public events)            0.878229
# 67                  (require cancelling public events)            0.642066
# 69                  (require cancelling public events)            0.767528
# 76           (no restrictions on international travel)            0.450185
# 82           (no restrictions on international travel)            0.464945
# 88           (no restrictions on international travel)            0.431734
# 100                 (require cancelling public events)            0.431734
# 107          (no restrictions on international travel)            0.464945
# 114   (recommend not to travel between regions/cities)            0.464945
# 119                 (require cancelling public events)            0.464945
# 125         (no measures for stay at home requirement)            0.509225
# 126  (require closing (or work from home) for some ...            0.464945
# 131          (no restrictions on international travel)            0.586716
# 132   (recommend not to travel between regions/cities)            0.586716
# 135  (recommend not to travel between regions/citie...            0.586716
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              1.000000  0.509225    1.000000  1.000000  0.000000         inf
# 11             1.000000  0.586716    1.000000  1.000000  0.000000         inf
# 13             0.771218  0.586716    1.000000  1.296651  0.134230         inf
# 15             0.955720  0.586716    1.000000  1.046332  0.025980         inf
# 20             1.000000  0.627306    1.000000  1.000000  0.000000         inf
# 30             1.000000  0.797048    1.000000  1.000000  0.000000         inf
# 32             1.000000  0.424354    1.000000  1.000000  0.000000         inf
# 34             1.000000  0.771218    1.000000  1.000000  0.000000         inf
# 36             1.000000  0.955720    1.000000  1.000000  0.000000         inf
# 38             1.000000  0.878229    1.000000  1.000000  0.000000         inf
# 41             1.000000  0.642066    1.000000  1.000000  0.000000         inf
# 43             1.000000  0.767528    1.000000  1.000000  0.000000         inf
# 44             0.797048  0.420664    0.991304  1.243720  0.082434   23.339483
# 53             0.797048  0.642066    1.000000  1.254630  0.130309         inf
# 56             0.955720  0.771218    1.000000  1.046332  0.034150         inf
# 64             0.955720  0.878229    1.000000  1.046332  0.038888         inf
# 67             0.955720  0.642066    1.000000  1.046332  0.028431         inf
# 69             0.955720  0.767528    1.000000  1.046332  0.033986         inf
# 76             1.000000  0.450185    1.000000  1.000000  0.000000         inf
# 82             1.000000  0.464945    1.000000  1.000000  0.000000         inf
# 88             1.000000  0.431734    1.000000  1.000000  0.000000         inf
# 100            0.955720  0.431734    1.000000  1.046332  0.019117         inf
# 107            1.000000  0.464945    1.000000  1.000000  0.000000         inf
# 114            0.771218  0.464945    1.000000  1.296651  0.106371         inf
# 119            0.955720  0.464945    1.000000  1.046332  0.020588         inf
# 125            0.627306  0.464945    0.913043  1.455499  0.145505    4.285978
# 126            0.878229  0.464945    1.000000  1.138655  0.056617         inf
# 131            1.000000  0.586716    1.000000  1.000000  0.000000         inf
# 132            0.771218  0.586716    1.000000  1.296651  0.134230         inf
# 135            0.771218  0.586716    1.000000  1.296651  0.134230         inf
#
#      antecedent_len
# 0                 1
# 11                1
# 13                1
# 15                1
# 20                1
# 30                1
# 32                1
# 34                1
# 36                1
# 38                1
# 41                1
# 43                1
# 44                1
# 53                1
# 56                1
# 64                1
# 67                1
# 69                1
# 76                2
# 82                2
# 88                2
# 100               2
# 107               2
# 114               2
# 119               2
# 125               2
# 126               2
# 131               2
# 132               2
# 135               1

# %% [markdown]
# ## Early Breakout/Spring Period

# %%
#Early breakout period

all_elements = OR_basket_EB.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in OR during Spring', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %% [markdown]
# As we can maybe see from the chart above, the "screeing arrivals on international travel" shows up in 100% of the days, so we can leave that out to avoid any skew.

# %%
basket_array_EB = OR_basket_EB.values
basket_cols_EB = OR_basket_EB.columns
te_EB = TransactionEncoder()
te_dataset_EB = te_EB.fit(basket_array_EB).transform(basket_array_EB)

OR_te_basket_EB = pd.DataFrame(te_dataset_EB, columns = te_EB.columns_)

# %%
# EB period

OR_freq_itemsets_EB = apriori(OR_te_basket_EB, min_support=0.4, use_colnames=True)
OR_freq_itemsets_EB['length'] = OR_freq_itemsets_EB['itemsets'].apply(lambda x: len(x))
rules_EB = association_rules(OR_freq_itemsets_EB, metric="conviction", min_threshold=0.3)
rules_EB["antecedent_len"] = rules_EB["antecedents"].apply(lambda x: len(x))

# %%
trimmed_rules_EB = rules_EB[(rules_EB['confidence'] >= 0.7) & (rules_EB['conviction'] >= 3) & (rules_EB['support'] >= 0.6)]
trimmed_rules_EB.head(30)
# Out:
#                                            antecedents  \
# 36   (only those who both (a) have symptoms AND (b)...
# 40                  (require cancelling public events)
# 42   (require closing (or work from home) for some ...
# 45        (require closing all levels, school closing)
# 46   (require not leaving house with exceptions for...
# 49   (restrictions on gatherings of 10 people or less)
# 52                  (require cancelling public events)
# 54   (require closing (or work from home) for some ...
# 57        (require closing all levels, school closing)
# 58   (require not leaving house with exceptions for...
# 61   (restrictions on gatherings of 10 people or less)
# 72   (require closing (or work from home) for some ...
# 73                  (require cancelling public events)
# 74                  (require cancelling public events)
# 75        (require closing all levels, school closing)
# 76   (require not leaving house with exceptions for...
# 79   (restrictions on gatherings of 10 people or less)
# 80   (require closing (or work from home) for some ...
# 81        (require closing all levels, school closing)
# 83   (require not leaving house with exceptions for...
# 85   (restrictions on gatherings of 10 people or less)
# 86   (require not leaving house with exceptions for...
# 88   (restrictions on gatherings of 10 people or less)
# 90   (require not leaving house with exceptions for...
# 91   (restrictions on gatherings of 10 people or less)
# 356  (only those who both (a) have symptoms AND (b)...
# 357  (require cancelling public events, no restrict...
# 359                 (require cancelling public events)
# 362  (require closing (or work from home) for some ...
# 363  (require closing (or work from home) for some ...
#
#                                            consequents  antecedent support  \
# 36           (no restrictions on international travel)            0.988764
# 40           (no restrictions on international travel)            0.865169
# 42           (no restrictions on international travel)            0.865169
# 45           (no restrictions on international travel)            0.842697
# 46           (no restrictions on international travel)            0.741573
# 49           (no restrictions on international travel)            0.741573
# 52   (only those who both (a) have symptoms AND (b)...            0.865169
# 54   (only those who both (a) have symptoms AND (b)...            0.865169
# 57   (only those who both (a) have symptoms AND (b)...            0.842697
# 58   (only those who both (a) have symptoms AND (b)...            0.741573
# 61   (only those who both (a) have symptoms AND (b)...            0.741573
# 72                  (require cancelling public events)            0.865169
# 73   (require closing (or work from home) for some ...            0.865169
# 74        (require closing all levels, school closing)            0.865169
# 75                  (require cancelling public events)            0.842697
# 76                  (require cancelling public events)            0.741573
# 79                  (require cancelling public events)            0.741573
# 80        (require closing all levels, school closing)            0.865169
# 81   (require closing (or work from home) for some ...            0.842697
# 83   (require closing (or work from home) for some ...            0.741573
# 85   (require closing (or work from home) for some ...            0.741573
# 86        (require closing all levels, school closing)            0.741573
# 88        (require closing all levels, school closing)            0.741573
# 90   (restrictions on gatherings of 10 people or less)            0.741573
# 91   (require not leaving house with exceptions for...            0.741573
# 356          (no restrictions on international travel)            0.865169
# 357  (only those who both (a) have symptoms AND (b)...            0.865169
# 359  (only those who both (a) have symptoms AND (b)...            0.865169
# 362          (no restrictions on international travel)            0.865169
# 363  (only those who both (a) have symptoms AND (b)...            0.865169
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 36             1.000000  0.988764    1.000000  1.000000  0.000000         inf
# 40             1.000000  0.865169    1.000000  1.000000  0.000000         inf
# 42             1.000000  0.865169    1.000000  1.000000  0.000000         inf
# 45             1.000000  0.842697    1.000000  1.000000  0.000000         inf
# 46             1.000000  0.741573    1.000000  1.000000  0.000000         inf
# 49             1.000000  0.741573    1.000000  1.000000  0.000000         inf
# 52             0.988764  0.865169    1.000000  1.011364  0.009721         inf
# 54             0.988764  0.865169    1.000000  1.011364  0.009721         inf
# 57             0.988764  0.842697    1.000000  1.011364  0.009469         inf
# 58             0.988764  0.741573    1.000000  1.011364  0.008332         inf
# 61             0.988764  0.741573    1.000000  1.011364  0.008332         inf
# 72             0.865169  0.865169    1.000000  1.155844  0.116652         inf
# 73             0.865169  0.865169    1.000000  1.155844  0.116652         inf
# 74             0.842697  0.842697    0.974026  1.155844  0.113622     6.05618
# 75             0.865169  0.842697    1.000000  1.155844  0.113622         inf
# 76             0.865169  0.741573    1.000000  1.155844  0.099987         inf
# 79             0.865169  0.741573    1.000000  1.155844  0.099987         inf
# 80             0.842697  0.842697    0.974026  1.155844  0.113622     6.05618
# 81             0.865169  0.842697    1.000000  1.155844  0.113622         inf
# 83             0.865169  0.741573    1.000000  1.155844  0.099987         inf
# 85             0.865169  0.741573    1.000000  1.155844  0.099987         inf
# 86             0.842697  0.741573    1.000000  1.186667  0.116652         inf
# 88             0.842697  0.741573    1.000000  1.186667  0.116652         inf
# 90             0.741573  0.741573    1.000000  1.348485  0.191642         inf
# 91             0.741573  0.741573    1.000000  1.348485  0.191642         inf
# 356            1.000000  0.865169    1.000000  1.000000  0.000000         inf
# 357            0.988764  0.865169    1.000000  1.011364  0.009721         inf
# 359            0.988764  0.865169    1.000000  1.011364  0.009721         inf
# 362            1.000000  0.865169    1.000000  1.000000  0.000000         inf
# 363            0.988764  0.865169    1.000000  1.011364  0.009721         inf
#
#      antecedent_len
# 36                1
# 40                1
# 42                1
# 45                1
# 46                1
# 49                1
# 52                1
# 54                1
# 57                1
# 58                1
# 61                1
# 72                1
# 73                1
# 74                1
# 75                1
# 76                1
# 79                1
# 80                1
# 81                1
# 83                1
# 85                1
# 86                1
# 88                1
# 90                1
# 91                1
# 356               2
# 357               2
# 359               1
# 362               2
# 363               2

# %% [markdown]
# ## Summer Period

# %%
#summer period

all_elements = OR_basket_summer.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in OR during summer', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %%
basket_array_summer = OR_basket_summer.values
basket_cols_summer = OR_basket_summer.columns
te_summer = TransactionEncoder()
te_dataset_summer = te_summer.fit(basket_array_summer).transform(basket_array_summer)

OR_te_basket_summer = pd.DataFrame(te_dataset_summer, columns = te_summer.columns_)

# %%
# summer period

OR_freq_itemsets_summer = apriori(OR_te_basket_summer, min_support=0.6, use_colnames=True)
OR_freq_itemsets_summer['length'] = OR_freq_itemsets_summer['itemsets'].apply(lambda x: len(x))
rules_summer = association_rules(OR_freq_itemsets_summer, metric="conviction", min_threshold=0.3)
rules_summer["antecedent_len"] = rules_summer["antecedents"].apply(lambda x: len(x))

# %%
trimmed_rules_summer = rules_summer[(rules_summer['confidence'] >= 0.7) & 
                                    (rules_summer['support'] >= 0.7) & 
                                    (rules_summer['conviction'] > 1) &
                                    (rules_summer['lift'] > 1)]
trimmed_rules_summer.head(40)
# Out:
#                                            antecedents  \
# 18   (require closing (or work from home) for some ...
# 19          (no measures for stay at home requirement)
# 131  (require closing (or work from home) for some ...
# 132  (no measures for stay at home requirement, no ...
# 133  (require closing (or work from home) for some ...
# 134         (no measures for stay at home requirement)
# 155  (require closing (or work from home) for some ...
# 156  (no measures for stay at home requirement, onl...
# 157  (require closing (or work from home) for some ...
# 158         (no measures for stay at home requirement)
# 173  (require closing (or work from home) for some ...
# 174  (recommend not to travel between regions/citie...
# 175  (require closing (or work from home) for some ...
# 176         (no measures for stay at home requirement)
# 185  (require closing (or work from home) for some ...
# 186  (no measures for stay at home requirement, req...
# 187  (require closing (or work from home) for some ...
# 188         (no measures for stay at home requirement)
# 197  (require closing (or work from home) for some ...
# 198  (no measures for stay at home requirement, req...
# 199  (require closing (or work from home) for some ...
# 200         (no measures for stay at home requirement)
# 491  (require closing (or work from home) for some ...
# 493  (no measures for stay at home requirement, onl...
# 494  (require closing (or work from home) for some ...
# 496  (require closing (or work from home) for some ...
# 497  (no measures for stay at home requirement, onl...
# 499  (no measures for stay at home requirement, no ...
# 500  (require closing (or work from home) for some ...
# 502         (no measures for stay at home requirement)
# 534  (require closing (or work from home) for some ...
# 535  (recommend not to travel between regions/citie...
# 537  (require closing (or work from home) for some ...
# 538  (require closing (or work from home) for some ...
# 539  (no measures for stay at home requirement, no ...
# 540  (recommend not to travel between regions/citie...
# 542  (require closing (or work from home) for some ...
# 543         (no measures for stay at home requirement)
# 562  (require closing (or work from home) for some ...
# 563  (require cancelling public events, no measures...
#
#                                            consequents  antecedent support  \
# 18          (no measures for stay at home requirement)            0.771739
# 19   (require closing (or work from home) for some ...            0.750000
# 131         (no measures for stay at home requirement)            0.771739
# 132  (require closing (or work from home) for some ...            0.750000
# 133  (no measures for stay at home requirement, no ...            0.771739
# 134  (require closing (or work from home) for some ...            0.750000
# 155         (no measures for stay at home requirement)            0.771739
# 156  (require closing (or work from home) for some ...            0.750000
# 157  (no measures for stay at home requirement, onl...            0.771739
# 158  (require closing (or work from home) for some ...            0.750000
# 173         (no measures for stay at home requirement)            0.771739
# 174  (require closing (or work from home) for some ...            0.750000
# 175  (recommend not to travel between regions/citie...            0.771739
# 176  (require closing (or work from home) for some ...            0.750000
# 185         (no measures for stay at home requirement)            0.771739
# 186  (require closing (or work from home) for some ...            0.750000
# 187  (no measures for stay at home requirement, req...            0.771739
# 188  (require closing (or work from home) for some ...            0.750000
# 197         (no measures for stay at home requirement)            0.771739
# 198  (require closing (or work from home) for some ...            0.750000
# 199  (no measures for stay at home requirement, req...            0.771739
# 200  (require closing (or work from home) for some ...            0.750000
# 491         (no measures for stay at home requirement)            0.771739
# 493  (require closing (or work from home) for some ...            0.750000
# 494  (no measures for stay at home requirement, no ...            0.771739
# 496  (no measures for stay at home requirement, onl...            0.771739
# 497  (require closing (or work from home) for some ...            0.750000
# 499  (require closing (or work from home) for some ...            0.750000
# 500  (no measures for stay at home requirement, onl...            0.771739
# 502  (require closing (or work from home) for some ...            0.750000
# 534         (no measures for stay at home requirement)            0.771739
# 535  (require closing (or work from home) for some ...            0.750000
# 537  (recommend not to travel between regions/citie...            0.771739
# 538  (no measures for stay at home requirement, no ...            0.771739
# 539  (require closing (or work from home) for some ...            0.750000
# 540  (require closing (or work from home) for some ...            0.750000
# 542  (recommend not to travel between regions/citie...            0.771739
# 543  (require closing (or work from home) for some ...            0.750000
# 562         (no measures for stay at home requirement)            0.771739
# 563  (require closing (or work from home) for some ...            0.750000
#
#      consequent support  support  confidence      lift  leverage  conviction  \
# 18             0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 19             0.771739     0.75    1.000000  1.295775  0.171196         inf
# 131            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 132            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 133            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 134            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 155            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 156            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 157            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 158            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 173            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 174            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 175            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 176            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 185            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 186            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 187            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 188            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 197            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 198            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 199            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 200            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 491            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 493            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 494            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 496            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 497            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 499            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 500            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 502            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 534            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 535            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 537            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 538            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 539            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 540            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 542            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 543            0.771739     0.75    1.000000  1.295775  0.171196         inf
# 562            0.750000     0.75    0.971831  1.295775  0.171196       8.875
# 563            0.771739     0.75    1.000000  1.295775  0.171196         inf
#
#      antecedent_len
# 18                1
# 19                1
# 131               2
# 132               2
# 133               1
# 134               1
# 155               2
# 156               2
# 157               1
# 158               1
# 173               2
# 174               2
# 175               1
# 176               1
# 185               2
# 186               2
# 187               1
# 188               1
# 197               2
# 198               2
# 199               1
# 200               1
# 491               3
# 493               3
# 494               2
# 496               2
# 497               2
# 499               2
# 500               1
# 502               1
# 534               3
# 535               3
# 537               2
# 538               2
# 539               2
# 540               2
# 542               1
# 543               1
# 562               3
# 563               3

# %% [markdown]
# ## Fall Period

# %%
#fall period

all_elements = OR_basket_fall.values.tolist()
flat_list = [item for sublist in all_elements for item in sublist]
temp_df = pd.DataFrame({'col':flat_list})


plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
temp_df['col'].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular "items" in OR during Fall', fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %% [markdown]
# Now that we have the data set up as a series of 'transactions' with items (basket), we just need to encode the items and then use Apriori analysis and find association rules:

# %%
basket_array_fall = OR_basket_fall.values
basket_cols_fall = OR_basket_fall.columns
te_fall = TransactionEncoder()
te_dataset_fall = te_fall.fit(basket_array_fall).transform(basket_array_fall)

OR_te_basket_fall = pd.DataFrame(te_dataset_fall, columns = te_fall.columns_)

# %%
OR_te_basket_full.head()
# Out:
#    deathIncrease(-0.021, 2.1]  deathIncrease(10.5, 12.6]  \
# 0                        True                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
#
#    deathIncrease(12.6, 14.7]  deathIncrease(14.7, 16.8]  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    deathIncrease(18.9, 21.0]  deathIncrease(2.1, 4.2]  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
#
#    deathIncrease(4.2, 6.3]  deathIncrease(6.3, 8.4]  deathIncrease(8.4, 10.5]  \
# 0                    False                    False                     False
# 1                    False                    False                     False
# 2                    False                    False                     False
# 3                    False                    False                     False
# 4                    False                    False                     False
#
#    facial coverings required in all shared/public spaces  ...  \
# 0                                              False      ...
# 1                                              False      ...
# 2                                              False      ...
# 3                                              False      ...
# 4                                              False      ...
#
#    totalTestResultsIncrease(-12.408, 1240.8]  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
#
#    totalTestResultsIncrease(11167.2, 12408.0]  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    totalTestResultsIncrease(1240.8, 2481.6]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(2481.6, 3722.4]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(3722.4, 4963.2]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(4963.2, 6204.0]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(6204.0, 7444.8]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(7444.8, 8685.6]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(8685.6, 9926.4]  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    totalTestResultsIncrease(9926.4, 11167.2]
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
# [5 rows x 73 columns]

# %% [markdown]
# Performing apriori and then creating association rules for all periods:

# %%
# fall period

OR_freq_itemsets_fall = apriori(OR_te_basket_fall, min_support=0.4, use_colnames=True)
OR_freq_itemsets_fall['length'] = OR_freq_itemsets_fall['itemsets'].apply(lambda x: len(x))
rules_fall = association_rules(OR_freq_itemsets_fall, metric="conviction", min_threshold=0.3)
rules_fall["antecedent_len"] = rules_fall["antecedents"].apply(lambda x: len(x))

# %% [markdown]
# Now we can mine for associations:

# %%
rules.to_csv("Oregon.csv")

# %%
OR_basket_full['positiveIncrease'].unique()
# Out:
# array(['positiveIncrease(-1.674, 167.4]',
#        'positiveIncrease(167.4, 334.8]', 'positiveIncrease(334.8, 502.2]',
#        'positiveIncrease(502.2, 669.6]', 'positiveIncrease(669.6, 837.0]',
#        'positiveIncrease(837.0, 1004.4]',
#        'positiveIncrease(1004.4, 1171.8]',
#        'positiveIncrease(1171.8, 1339.2]',
#        'positiveIncrease(1339.2, 1506.6]',
#        'positiveIncrease(1506.6, 1674.0]'], dtype=object)
